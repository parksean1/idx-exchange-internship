# %% [markdown]
# # Listing Week 1

# %%
import pandas as pd
import glob

listing_files = sorted(glob.glob('../../IDX_Data/CRMLSListing*.csv'))

listing_list = []
listing_rows_before = 0

for file in listing_files:
    df = pd.read_csv(file)
    listing_rows_before += len(df)
    listing_list.append(df)

print("LISTING — Total rows BEFORE concat:", listing_rows_before)
# Out:
# LISTING — Total rows BEFORE concat: 855840

# %%
listing = pd.concat(listing_list, ignore_index=True)
print("LISTING — Rows AFTER concat:", listing.shape[0])
# Out:
# LISTING — Rows AFTER concat: 855840

# %%
listing.head()
# Out:
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# 2       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 3       NaN         NaN              Renee              Chen  33.496363
# 4       NaN         NaN           Margaret             Nader  34.119345
#
#     Longitude                UnparsedAddress  ... MainLevelBedrooms  \
# ...

# %%
listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
# ...

# %%
print(f'Listing shape: {listing.shape}\n')
listing.info()
# Out:
# Listing shape: (855840, 84)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 855840 entries, 0 to 855839
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             852516 non-null  float64
#  1   ListingKey                    855840 non-null  int64
#  2   ListAgentEmail                780379 non-null  str
#  3   CloseDate                     255338 non-null  str
#  4   ClosePrice                    232424 non-null  float64
#  5   ListAgentFirstName            850814 non-null  str
#  6   ListAgentLastName             855763 non-null  str
#  7   Latitude                      743883 non-null  float64
#  8   Longitude                     744588 non-null  float64
#  9   UnparsedAddress               853673 non-null  str
#  10  PropertyType                  855840 non-null  str
#  11  LivingArea                    749161 non-null  float64
# ...

# %%
# Check property types
print("LISTING Property Types:", listing['PropertyType'].unique())

# Filter Residential
listing_res = listing[listing['PropertyType'] == 'Residential']
print("LISTING — Rows AFTER Residential filter:", listing_res.shape[0])
# Out:
# LISTING Property Types: <StringArray>
# [ 'ManufacturedInPark',      'CommercialSale',         'Residential',
#     'ResidentialLease',                'Land',   'ResidentialIncome',
#      'CommercialLease', 'BusinessOpportunity']
# Length: 8, dtype: str
# LISTING — Rows AFTER Residential filter: 542075

# %%
listing_res.to_csv("listing_combined_residential.csv", index=False)
print("LISTING dataset saved.")
# Out:
# LISTING dataset saved.
