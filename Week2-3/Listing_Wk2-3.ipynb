# %% [markdown]
# # Listing Weeks 2-3

# %%
import pandas as pd
import numpy as np

listing = pd.read_csv("../../IDX_Data/listing_combined_residential.csv")
print("Shape:", listing.shape)
listing.head()
# Out:
# /var/folders/hx/s9px6scd2pl5dqfp0pldbdgc0000gn/T/ipykernel_71322/683367248.py:4: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing = pd.read_csv("../../IDX_Data/listing_combined_residential.csv")
# Shape: (542075, 84)
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0          1340000.0  1074973329                    haleh360@Gmail.com
# 1          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 2          3150000.0  1074936537                      anader@dppre.com
# 3          3090000.0  1074917818                  QIANYU0607@GMAIL.COM
# 4         12725000.0  1074143166          jeff.williams@pacificsir.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 1       NaN         NaN              Renee              Chen  33.496363
# 2       NaN         NaN           Margaret             Nader  34.119345
# 3       NaN         NaN             QIANYU              GUAN  33.984057
# 4       NaN         NaN               Jeff          Williams  33.607583
#
#     Longitude                UnparsedAddress  ... MainLevelBedrooms  \
# 0 -118.408445  2220 Avenue Of The Stars 2704  ...               NaN
# 1 -117.691677                   16 Palisades  ...               0.0
# 2 -118.111254              1615 Waverly Road  ...               NaN
# 3 -117.802819         2250 Indian Creek Road  ...               1.0
# 4 -117.887743                317 E. Bayfront  ...               3.0
#
#    NewConstructionYN  GarageSpaces     HighSchoolDistrict PostalCode  \
# 0              False           NaN                    NaN      90067
# 1              False           3.0     Capistrano Unified      92677
# 2                NaN           2.0                    NaN      91108
# 3              False           4.0  Walnut Valley Unified      91765
# 4              False           2.0   Newport Mesa Unified      92662
#
#   BuyerOfficeName.1 AssociationFee LotSizeSquareFeet  \
# 0               NaN        2105.00          177861.0
# 1               NaN         254.00            5300.0
# 2               NaN            NaN            9404.0
# 3               NaN         295.95           58232.0
# 4               NaN           0.00            2250.0
#
#   MiddleOrJuniorSchoolDistrict              UnparsedAddress.1
# 0                          NaN  2220 Avenue Of The Stars 2704
# 1                          NaN                   16 Palisades
# 2                          NaN              1615 Waverly Road
# 3                          NaN         2250 Indian Creek Road
# 4                          NaN                317 E. Bayfront
#
# [5 rows x 84 columns]

# %%
listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'BuyerAgencyCompensation',
#        'TaxYear', 'BuildingAreaTotal', 'BedroomsTotal',
#        'ContractStatusChangeDate', 'Longitude.1', 'ElementarySchoolDistrict',
#        'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate',
#        'BelowGradeFinishedArea', 'BusinessType', 'Latitude.1', 'ListPrice.1',
#        'StateOrProvince', 'CoveredSpaces', 'MiddleOrJuniorSchool',
#        'FireplaceYN', 'Stories', 'HighSchool', 'Levels', 'ListAgentLastName.1',
#        'CloseDate.1', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'BuyerOfficeName.1', 'AssociationFee', 'LotSizeSquareFeet',
#        'MiddleOrJuniorSchoolDistrict', 'UnparsedAddress.1'],
#       dtype='str')

# %%
listing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 542075 entries, 0 to 542074
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             541305 non-null  float64
#  1   ListingKey                    542075 non-null  int64
#  2   ListAgentEmail                493182 non-null  str
#  3   CloseDate                     161516 non-null  str
#  4   ClosePrice                    140928 non-null  float64
#  5   ListAgentFirstName            537816 non-null  str
#  6   ListAgentLastName             542035 non-null  str
#  7   Latitude                      461900 non-null  float64
#  8   Longitude                     461900 non-null  float64
#  9   UnparsedAddress               541374 non-null  str
#  10  PropertyType                  542075 non-null  str
#  11  LivingArea                    541519 non-null  float64
#  12  ListPrice                     542075 non-null  float64
#  13  DaysOnMarket                  542075 non-null  int64
#  14  ListOfficeName                542075 non-null  str
#  15  BuyerOfficeName               152535 non-null  str
#  16  CoListOfficeName              121361 non-null  str
#  17  ListAgentFullName             541984 non-null  str
#  18  CoListAgentFirstName          120876 non-null  str
#  19  CoListAgentLastName           121276 non-null  str
#  20  BuyerAgentMlsId               154613 non-null  str
#  21  BuyerAgentFirstName           154009 non-null  str
#  22  BuyerAgentLastName            154718 non-null  str
#  23  FireplacesTotal               0 non-null       float64
#  24  AssociationFeeFrequency       231711 non-null  str
#  25  AboveGradeFinishedArea        0 non-null       float64
#  26  ListingKeyNumeric             542075 non-null  int64
#  27  MLSAreaMajor                  468791 non-null  str
#  28  TaxAnnualAmount               0 non-null       float64
#  29  CountyOrParish                542075 non-null  str
#  30  PropertyType.1                542075 non-null  str
#  31  MlsStatus                     542075 non-null  str
#  32  ElementarySchool              64580 non-null   str
#  33  ListAgentFirstName.1          537816 non-null  str
#  34  AttachedGarageYN              447352 non-null  object
#  35  ParkingTotal                  542055 non-null  float64
#  36  BuilderName                   25282 non-null   str
#  37  PropertySubType               540819 non-null  str
#  38  LotSizeAcres                  497361 non-null  float64
#  39  SubdivisionName               199519 non-null  str
#  40  BuyerOfficeAOR                142741 non-null  str
#  41  YearBuilt                     541141 non-null  float64
#  42  DaysOnMarket.1                542075 non-null  int64
#  43  BuyerAgencyCompensationType   79013 non-null   str
#  44  StreetNumberNumeric           541194 non-null  float64
#  45  LivingArea.1                  541519 non-null  float64
#  46  ListingId                     542075 non-null  str
#  47  BathroomsTotalInteger         542019 non-null  float64
#  48  City                          541499 non-null  str
#  49  BuyerAgencyCompensation       78993 non-null   float64
#  50  TaxYear                       0 non-null       float64
#  51  BuildingAreaTotal             48165 non-null   float64
#  52  BedroomsTotal                 541925 non-null  float64
#  53  ContractStatusChangeDate      535937 non-null  str
#  54  Longitude.1                   461900 non-null  float64
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         13966 non-null   str
#  57  PurchaseContractDate          263221 non-null  str
#  58  ListingContractDate           542075 non-null  str
#  59  BelowGradeFinishedArea        3036 non-null    float64
#  60  BusinessType                  0 non-null       float64
#  61  Latitude.1                    461900 non-null  float64
#  62  ListPrice.1                   542075 non-null  float64
#  63  StateOrProvince               542022 non-null  str
#  64  CoveredSpaces                 0 non-null       float64
#  65  MiddleOrJuniorSchool          64706 non-null   str
#  66  FireplaceYN                   541500 non-null  object
#  67  Stories                       447137 non-null  float64
#  68  HighSchool                    84748 non-null   str
#  69  Levels                        483472 non-null  str
#  70  ListAgentLastName.1           542035 non-null  str
#  71  CloseDate.1                   161516 non-null  str
#  72  LotSizeDimensions             28287 non-null   str
#  73  LotSizeArea                   498202 non-null  float64
#  74  MainLevelBedrooms             294718 non-null  float64
#  75  NewConstructionYN             504800 non-null  object
#  76  GarageSpaces                  511960 non-null  float64
#  77  HighSchoolDistrict            379088 non-null  str
#  78  PostalCode                    542062 non-null  str
#  79  BuyerOfficeName.1             152535 non-null  str
#  80  AssociationFee                411749 non-null  float64
#  81  LotSizeSquareFeet             498027 non-null  float64
#  82  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  83  UnparsedAddress.1             541374 non-null  str
# dtypes: float64(33), int64(4), object(3), str(44)
# memory usage: 347.4+ MB

# %%
listing['PropertyType'].unique()
# Out:
# <StringArray>
# ['Residential']
# Length: 1, dtype: str

# %%
print("Property Types:", listing['PropertyType'].unique())

# Filter to Residential
listing = listing[listing['PropertyType'] == 'Residential']
print("Shape after Residential filter:", listing.shape)
# Out:
# Property Types: <StringArray>
# ['Residential']
# Length: 1, dtype: str
# Shape after Residential filter: (542075, 84)

# %%
null_counts = listing.isnull().sum()
null_counts.sort_values(ascending=False).head(20)
# Out:
# TaxAnnualAmount                 542075
# FireplacesTotal                 542075
# ElementarySchoolDistrict        542075
# TaxYear                         542075
# BusinessType                    542075
# MiddleOrJuniorSchoolDistrict    542075
# CoveredSpaces                   542075
# AboveGradeFinishedArea          542075
# BelowGradeFinishedArea          539039
# CoBuyerAgentFirstName           528109
# BuilderName                     516793
# LotSizeDimensions               513788
# BuildingAreaTotal               493910
# ElementarySchool                477495
# MiddleOrJuniorSchool            477369
# BuyerAgencyCompensation         463082
# BuyerAgencyCompensationType     463062
# HighSchool                      457327
# CoListAgentFirstName            421199
# CoListAgentLastName             420799
# dtype: int64

# %%
missing_pct = (listing.isnull().sum() / len(listing)) * 100
missing_df = pd.DataFrame({
    'missing_count': listing.isnull().sum(),
    'missing_pct': missing_pct
}).sort_values(by='missing_pct', ascending=False)

missing_df.head(20)
# Out:
#                               missing_count  missing_pct
# TaxAnnualAmount                      542075   100.000000
# FireplacesTotal                      542075   100.000000
# ElementarySchoolDistrict             542075   100.000000
# TaxYear                              542075   100.000000
# BusinessType                         542075   100.000000
# MiddleOrJuniorSchoolDistrict         542075   100.000000
# CoveredSpaces                        542075   100.000000
# AboveGradeFinishedArea               542075   100.000000
# BelowGradeFinishedArea               539039    99.439930
# CoBuyerAgentFirstName                528109    97.423604
# BuilderName                          516793    95.336070
# LotSizeDimensions                    513788    94.781718
# BuildingAreaTotal                    493910    91.114698
# ElementarySchool                     477495    88.086519
# MiddleOrJuniorSchool                 477369    88.063275
# BuyerAgencyCompensation              463082    85.427662
# BuyerAgencyCompensationType          463062    85.423973
# HighSchool                           457327    84.366001
# CoListAgentFirstName                 421199    77.701241
# CoListAgentLastName                  420799    77.627450

# %%
high_missing = missing_df[missing_df['missing_pct'] > 90]
high_missing
# Out:
#                               missing_count  missing_pct
# TaxAnnualAmount                      542075   100.000000
# FireplacesTotal                      542075   100.000000
# ElementarySchoolDistrict             542075   100.000000
# TaxYear                              542075   100.000000
# BusinessType                         542075   100.000000
# MiddleOrJuniorSchoolDistrict         542075   100.000000
# CoveredSpaces                        542075   100.000000
# AboveGradeFinishedArea               542075   100.000000
# BelowGradeFinishedArea               539039    99.439930
# CoBuyerAgentFirstName                528109    97.423604
# BuilderName                          516793    95.336070
# LotSizeDimensions                    513788    94.781718
# BuildingAreaTotal                    493910    91.114698

# %%
listing[['ListPrice', 'LivingArea']].describe(
    percentiles=[0.01, 0.25, 0.5, 0.75, 0.99]
)
# Out:
#           ListPrice    LivingArea
# count  5.420750e+05  5.415190e+05
# mean   1.314032e+06  1.979827e+03
# std    2.346976e+06  2.334190e+04
# min    1.000000e+02  0.000000e+00
# 1%     2.100000e+05  5.880000e+02
# 25%    5.800000e+05  1.247000e+03
# 50%    8.450000e+05  1.669000e+03
# 75%    1.375000e+06  2.300000e+03
# 99%    8.200000e+06  6.300000e+03
# max    1.950000e+08  1.702132e+07

# %%
import matplotlib.pyplot as plt

cols = ['ListPrice', 'LivingArea']
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for i, col in enumerate(cols):
    data = listing[col].dropna()
    data = data[data > 0]  # safe for log
    
    axes[i].hist(data, bins=50)
    axes[i].set_title(col)
    axes[i].set_xscale('log')

plt.tight_layout()
plt.show()

# %%
listing.to_csv("listing_filtered_week2_3.csv", index=False)
print("Saved listing dataset.")
# Out:
# Saved listing dataset.
